# %%
data = [1,2,3,...]

# %%
test_data = data[0]
test_data =  {
      "book_name": "算法导论",
      "chapter": "技术 -> 一些比较难的问题 -> 练习",
      "content": "练习 1.1-1 给出一个真实世界的例子，其中包含着下列的某种计算问题：排序，确定多矩阵相乘的最佳顺序，或者找出凸壳。 1.1-2 除了运行速度以外，在真实世界问题背景中，还可以使用哪些效率指标？ 1.1-3 选择你原来见过的某种数据结构，讨论一下其长处和局限性。 1.1-4 上文中给出的最短路径问题和旅行商人问题有哪些相似之处？有哪些不同之处？ 1.1-5 举出一个现实世界的问题例子，它只能用最佳解决方案来解决。再举出另一个例子，在其中“近似”最优解决也足以解决问题"
    },

# %%
prompt1 = f"""{test_data["content"]} 重写这个question，作为一个简短的、清晰的、具体的、专业的、易于理解的问题，适用于学生思考回答。给我的回答只有这个重写后的question，不要包含其他内容。"""
response = llm(prompt1)
# print(response)

test_data =  {
      "book_name": "算法导论",
      "chapter": "技术 -> 一些比较难的问题 -> 练习",
      "content": "练习 1.1-1 给出一个真实世界的例子，其中包含着下列的某种计算问题：排序，确定多矩阵相乘的最佳顺序，或者找出凸壳。 1.1-2 除了运行速度以外，在真实世界问题背景中，还可以使用哪些效率指标？ 1.1-3 选择你原来见过的某种数据结构，讨论一下其长处和局限性。 1.1-4 上文中给出的最短路径问题和旅行商人问题有哪些相似之处？有哪些不同之处？ 1.1-5 举出一个现实世界的问题例子，它只能用最佳解决方案来解决。再举出另一个例子，在其中“近似”最优解决也足以解决问题"
      "question": response.strip()
    },

# %%
prompt2 = f"""{test_data["content"]} 重写这个question，作为一个简短的、清晰的、具体的、专业的、易于理解的问题，适用于学生思考回答。给我的回答只有这个重写后的question，不要包含其他内容。"""
response2 = llm(prompt2)
# print(response)

test_data =  {
      "book_name": "算法导论",
      "chapter": "技术 -> 一些比较难的问题 -> 练习",
      "content": "练习 1.1-1 给出一个真实世界的例子，其中包含着下列的某种计算问题：排序，确定多矩阵相乘的最佳顺序，或者找出凸壳。 1.1-2 除了运行速度以外，在真实世界问题背景中，还可以使用哪些效率指标？ 1.1-3 选择你原来见过的某种数据结构，讨论一下其长处和局限性。 1.1-4 上文中给出的最短路径问题和旅行商人问题有哪些相似之处？有哪些不同之处？ 1.1-5 举出一个现实世界的问题例子，它只能用最佳解决方案来解决。再举出另一个例子，在其中“近似”最优解决也足以解决问题"
      "question": 
      "answer": response2.strip()
    },
