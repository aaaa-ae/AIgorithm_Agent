# %%
texts = "" #书的内容
queries = get_knowledges(texts, llm)

# %%
queries = ["" , "" ,""] #知识点

# %%
for query in queies:
    query = "动态规划前置知识点有哪些" # eg

# %%
llm_resp = llm_call(query)
# llm_resp = ["数组", "递归",""]

# %%
def get_chunk(key, texts):
    # key = "数组" key2= "递归" ...
    texts = "xxxxxxxxxxxxxxx"
    key_chunks = ctrl_f(key,texts) #正则匹配
    # key_chunks = ["pre_key_100~after_key_100" , "" ,""]
    return key_chunks

# %%
def get_graph(key_chunks, key, query):
